# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools import TavilySearchResults
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from dotenv import load_dotenv
from langgraph.prebuilt import ToolNode

load_dotenv()

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools=tools)

def model(state: AgentState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])],
    }

def tools_router(state: AgentState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else:
        return END


tool_node = ToolNode(tools=tools)

graph = StateGraph(AgentState)

graph.add_node("model", model)
graph.add_node("tool_node", tool_node)
graph.set_entry_point("model")

graph.add_conditional_edges("model", tools_router)
graph.add_edge("tool_node", "model")

app = graph.compile()

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
input = {
    "messages": ["What's the current weather in Colombo?"]
}

events = app.stream(input=input, stream_mode="values")

for event in events:
    print(event["messages"])
# Out:
# [HumanMessage(content="What's the current weather in Colombo?", additional_kwargs={}, response_metadata={}, id='bcccbe66-00d8-4c61-993d-3ba3a8532bd3')]
# [HumanMessage(content="What's the current weather in Colombo?", additional_kwargs={}, response_metadata={}, id='bcccbe66-00d8-4c61-993d-3ba3a8532bd3'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'function': {'arguments': '{"query":"current weather in Colombo"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-50ac220c-506e-43bc-97b8-82ad7ad2c35f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Colombo'}, 'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [HumanMessage(content="What's the current weather in Colombo?", additional_kwargs={}, response_metadata={}, id='bcccbe66-00d8-4c61-993d-3ba3a8532bd3'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'function': {'arguments': '{"query":"current weather in Colombo"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-50ac220c-506e-43bc-97b8-82ad7ad2c35f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Colombo'}, 'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680", "content": "What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only"}, {"url": "https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399", "content": "1 day ago\\n\\n## Weather Near Colombo:\\n\\n...\\n\\n...\\n\\n... [...] # Colombo, Western\\n\\nColombo\\n\\nWestern\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Monthly\\n\\n## December\\n\\n## 2025\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### January 2026\\n\\n### February 2026\\n\\n### March 2026 [...] Geminid meteor shower peak to dazzle this weekend\\n\\n1 day ago\\n\\nFeatured Stories\\n\\nClimate\\n\\nUnderwater ‘storms’ are eating away at the Doomsday Glacier\\n\\n21 hours ago\\n\\nAstronomy\\n\\nBlack hole’s feeding frenzy triggers longest cosmic explosion on recor...\\n\\n18 hours ago\\n\\nWeather News\\n\\nRogue storms and climate chaos unleashed deadly flooding across Asia\\n\\n2 days ago\\n\\nAstronomy\\n\\nNew images show an interstellar comet\\n\\n23 hours ago\\n\\nWinter Weather\\n\\nWhat’s the best direction for your house to face?"}]', name='tavily_search_results_json', id='01afa75e-033e-444c-b5c0-157e4d3a7746', tool_call_id='call_t8lZXSt4BzoFzXUbThP1BZPb', artifact={'query': 'current weather in Colombo', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680', 'title': 'Weather Forecast for Colombo for Thursday 11 December', 'content': 'What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only', 'score': 0.99950445, 'raw_content': None}, {'url': 'https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399', 'title': 'Colombo, Western, Sri Lanka Monthly Weather - AccuWeather', 'content': '1 day ago\n\n## Weather Near Colombo:\n\n...\n\n...\n\n... [...] # Colombo, Western\n\nColombo\n\nWestern\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### ...
# [HumanMessage(content="What's the current weather in Colombo?", additional_kwargs={}, response_metadata={}, id='bcccbe66-00d8-4c61-993d-3ba3a8532bd3'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'function': {'arguments': '{"query":"current weather in Colombo"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-50ac220c-506e-43bc-97b8-82ad7ad2c35f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Colombo'}, 'id': 'call_t8lZXSt4BzoFzXUbThP1BZPb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680", "content": "What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only"}, {"url": "https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399", "content": "1 day ago\\n\\n## Weather Near Colombo:\\n\\n...\\n\\n...\\n\\n... [...] # Colombo, Western\\n\\nColombo\\n\\nWestern\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Monthly\\n\\n## December\\n\\n## 2025\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### January 2026\\n\\n### February 2026\\n\\n### March 2026 [...] Geminid meteor shower peak to dazzle this weekend\\n\\n1 day ago\\n\\nFeatured Stories\\n\\nClimate\\n\\nUnderwater ‘storms’ are eating away at the Doomsday Glacier\\n\\n21 hours ago\\n\\nAstronomy\\n\\nBlack hole’s feeding frenzy triggers longest cosmic explosion on recor...\\n\\n18 hours ago\\n\\nWeather News\\n\\nRogue storms and climate chaos unleashed deadly flooding across Asia\\n\\n2 days ago\\n\\nAstronomy\\n\\nNew images show an interstellar comet\\n\\n23 hours ago\\n\\nWinter Weather\\n\\nWhat’s the best direction for your house to face?"}]', name='tavily_search_results_json', id='01afa75e-033e-444c-b5c0-157e4d3a7746', tool_call_id='call_t8lZXSt4BzoFzXUbThP1BZPb', artifact={'query': 'current weather in Colombo', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680', 'title': 'Weather Forecast for Colombo for Thursday 11 December', 'content': 'What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only', 'score': 0.99950445, 'raw_content': None}, {'url': 'https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399', 'title': 'Colombo, Western, Sri Lanka Monthly Weather - AccuWeather', 'content': '1 day ago\n\n## Weather Near Colombo:\n\n...\n\n...\n\n... [...] # Colombo, Western\n\nColombo\n\nWestern\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### ...

# %%
input = {
    "messages": ["What's the current weather in Colombo?"]
}

events = app.stream(input=input, stream_mode="updates")

for event in events:
    print(event)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_B6aD7zrVHBRqoHJf1erB6RCN', 'function': {'arguments': '{"query":"current weather in Colombo"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-4afe6c11-b645-42ad-92e5-4678075d87bb-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Colombo'}, 'id': 'call_B6aD7zrVHBRqoHJf1erB6RCN', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tool_node': {'messages': [ToolMessage(content='[{"url": "https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680", "content": "What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only"}, {"url": "https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399", "content": "# Colombo, Western\\n\\nColombo\\n\\nWestern\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Monthly\\n\\n## December\\n\\n## 2025\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### January 2026\\n\\n### February 2026\\n\\n### March 2026 [...] Geminid meteor shower peak to dazzle this weekend\\n\\n1 day ago\\n\\nFeatured Stories\\n\\nClimate\\n\\nUnderwater ‘storms’ are eating away at the Doomsday Glacier\\n\\n21 hours ago\\n\\nAstronomy\\n\\nBlack hole’s feeding frenzy triggers longest cosmic explosion on recor...\\n\\n18 hours ago\\n\\nWeather News\\n\\nRogue storms and climate chaos unleashed deadly flooding across Asia\\n\\n2 days ago\\n\\nAstronomy\\n\\nNew images show an interstellar comet\\n\\n23 hours ago\\n\\nWinter Weather\\n\\nWhat’s the best direction for your house to face? [...] 1 day ago\\n\\n## Weather Near Colombo:\\n\\n...\\n\\n...\\n\\n..."}]', name='tavily_search_results_json', id='8b124794-6127-4c44-9d70-32baee18493f', tool_call_id='call_B6aD7zrVHBRqoHJf1erB6RCN', artifact={'query': 'current weather in Colombo', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.metcheck.com/WEATHER/dayforecast.asp?location=Colombo&dateFor=11/12/2025&locationID=1076450&lat=6.935480&lon=79.848680', 'title': 'Weather Forecast for Colombo for Thursday 11 December', 'content': 'What will the weather be like in Colombo on 11 December 2025. ... Weather Forecast for Colombo for Thursday 11 December. Day/Night. Day Only', 'score': 0.67321366, 'raw_content': None}, {'url': 'https://www.accuweather.com/en/lk/colombo/311399/december-weather/311399', 'title': 'Colombo, Western, Sri Lanka Monthly Weather - AccuWeather', 'content': '# Colombo, Western\n\nColombo\n\nWestern\n\n## Around the Globe\n\nAround the Globe\n\n### Hurricane Tracker\n\n### Radar & Maps\n\n### News & Features\n\n### Astronomy\n\n### Business\n\n### Climate\n\n### Health\n\n### Recreation\n\n### Sports\n\n### Travel\n\n### Warnings\n\n### Data Suite\n\n### Forensics\n\n### Advertising\n\n### Superior Accuracy™\n\n### Video\n\n## Monthly\n\n## December\n\n## 2025\n\n## Daily\n\n## Temperature Graph\n\n## Further Ahead\n\nFurther Ahead\n\n### January 2026\n\n### February 2026\n\n### March 2026 [...] Geminid meteor shower peak to dazzle this weekend\n\n1 day ago\n\nFeatured Stories\n\nClimate\n\nUnderwater ‘storms’ are eating away at the Doomsday Glacier\n\n21 hours ago\n\nAstronomy\n\nBlack hole’s feeding frenzy triggers longest cosmic explosion on recor...\n\n18 hours ago\n\nWeather News\n\nRogue storms and climate chaos unleashed deadly flooding across Asia\n\n2 days ago\n\nAstronomy\n\nNew images show an interstellar comet\n\n23 hours ago\n\nWinter Weather\n\nWhat’s the best direction for your house to face? [...] 1 day ago\n\n## Weather Near Colombo:\n\n...\n\n...\n\n...', 'score': 0.4784076, 'raw_content': None}], 'response_time': 2.71, 'request_id': '42eee56b-dc03-4676-ac2b-da65bb8dee87'})]}}
# {'model': {'messages': [AIMessage(content="I wasn't able to retrieve the exact current weather in Colombo from the search results. You might want to check a weather website or app like AccuWeather or the local meteorological service for the most up-to-date information.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 540, 'total_tokens': 585, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5', 'finish_reason': 'stop', 'logprobs': None}, id='run-fc760edd-4ece-4be8-8854-ec286e51f0e6-0', usage_metadata={'input_tokens': 540, 'output_tokens': 45, 'total_tokens': 585, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events:
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': 'LangGraph', 'tags': [], 'run_id': '99824703-18e9-444c-9092-0e5e27c6d1a0', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'run_id': '8dc23759-08a1-431e-9010-f09068c615e2', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': '053958f1-6d9a-46d5-943c-c1a6d4d2ab93', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '8dc23759-08a1-431e-9010-f09068c615e2']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': '053958f1-6d9a-46d5-943c-c1a6d4d2ab93', 'name': '_write', 'tags': ['seq:step:1', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '8dc23759-08a1-431e-9010-f09068c615e2']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'run_id': 'aa12852e-882e-4c2b-accc-fa04dba5da18', 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '8dc23759-08a1-431e-9010-f09068c615e2']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': 'aa12852e-882e-4c2b-accc-fa04dba5da18', 'name': '_write', 'tags': ['seq:step:3', 'langsmith:hidden', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '8dc23759-08a1-431e-9010-f09068c615e2']}
# {'event': 'on_chain_stream', 'run_id': '8dc23759-08a1-431e-9010-f09068c615e2', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'data': {'chunk': {'messages': ['Hi, how are you?']}}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': ['Hi, how are you?']}, 'input': {'messages': ['Hi, how are you?']}}, 'run_id': '8dc23759-08a1-431e-9010-f09068c615e2', 'name': '__start__', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ('__start__',), 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:18a7ebd7-0e85-b8ad-bdbf-3594a17f5a8f'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': '6b9e4796-6286-426c-86b7-705d1b59416d', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='Hello', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=" I'm", additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' here', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' help', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' your', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' questions', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' tasks', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' How', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' assist', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' today', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db'), 'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9')]]}}, 'run_id': '149eb763-ee04-49b8-a02d-2cf61c5644db', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'run_id': '21ece58b-9afc-4a76-a3d0-1a6293c0ce03', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}, 'input': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'run_id': '21ece58b-9afc-4a76-a3d0-1a6293c0ce03', 'name': '_write', 'tags': ['seq:step:2', 'langsmith:hidden'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9'), AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'name': 'tools_router', 'tags': ['seq:step:4'], 'run_id': '2e77e5fc-1cae-4e8f-a77f-3ba0537e9aa5', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9'), AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'run_id': '2e77e5fc-1cae-4e8f-a77f-3ba0537e9aa5', 'name': 'tools_router', 'tags': ['seq:step:4'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0', '6b9e4796-6286-426c-86b7-705d1b59416d']}
# {'event': 'on_chain_stream', 'run_id': '6b9e4796-6286-426c-86b7-705d1b59416d', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'data': {'chunk': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}, 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9')]}}, 'run_id': '6b9e4796-6286-426c-86b7-705d1b59416d', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model', 'start:model', 'tool_node'), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:d294b7d5-7c0d-99dd-1c52-04cb4ea661d2'}, 'parent_ids': ['99824703-18e9-444c-9092-0e5e27c6d1a0']}
# {'event': 'on_chain_stream', 'run_id': '99824703-18e9-444c-9092-0e5e27c6d1a0', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='b33cd01e-0fce-4d8d-8f2b-899f7aea0ae9'), AIMessage(content="Hello! I'm here to help you with your questions and tasks. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a4d13246c5'}, id='run-149eb763-ee04-49b8-a02d-2cf61c5644db')]}}, 'run_id': '99824703-18e9-444c-9092-0e5e27c6d1a0', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events:
    if event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True)
# Out:
# Hello! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?
